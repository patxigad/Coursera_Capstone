# %% [markdown]
# # Opening a self-service laundrette in London
# ## Business problem
# A good friend of mine wants to start her own business in London. She wants to open a self-service laundrette in London (in any borough) She has asked me to help her pull some data that can help her answer this question: Where should I open my business?
#
# ## Analytics approach
# After having a look at the different sources of data, I suggest we compile demographics data to create a choropleth that let us visually compare the different boroughs. Additionally, we are going to pull FourSquare data to see how many similar business are already stablished in London.
#
# Data Sources
# https://data.london.gov.uk/census/themes/migrant-population/
# https://foursquare.com/developers/apps

# %%
# Common standard libraries
import datetime
import time
import os

# Common external libraries
import pandas as pd
import numpy as np
import sklearn # scikit-learn
import requests
from bs4 import BeautifulSoup
import folium

# Visualization libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Setting plot appearance
# See here for more options: https://matplotlib.org/users/customizing.html
# %config InlineBackend.figure_format='retina'
sns.set() # Revert to matplotlib defaults
plt.rcParams['figure.figsize'] = (9, 6)
plt.rcParams['axes.labelpad'] = 10
sns.set_style("darkgrid")
# sns.set_context("poster", font_scale=1.0)

# Ignore warnings (don't display stderr)
import warnings
warnings.filterwarnings('ignore')

# %%
# Greater London, latitude and longtitude are manually extracted via google search
london_latitude = 51.509865; london_longitude = -0.118092
map_london = folium.Map(location = [london_latitude, london_longitude], zoom_start = 10.7)
boroughs = 'london_boroughs.geojson'
map_london.choropleth(
    geo_data=map_london,
    columns=['Neighbourhood', 'Count'],
    key_on='feature.properties.DISTRICT',
    threshold_scale=threshold_scale,
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Crime rate in San Francisco',
    reset=True
)

map_london
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6346b7dd7602> in <module>
#       5 map_london.choropleth(
#       6     geo_data=map_london,
# ----> 7     data=df,
#       8     columns=['Neighbourhood', 'Count'],
#       9     key_on='feature.properties.DISTRICT',
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('london-borough-profiles.csv')
df.head()
# Out:
#         Code   New code             Area name Inner/ Outer London  \
# 0  E09000001  E09000001        City of London        Inner London
# 1  E09000002  E09000002  Barking and Dagenham        Outer London
# 2  E09000003  E09000003                Barnet        Outer London
# 3  E09000004  E09000004                Bexley        Outer London
# 4  E09000005  E09000005                 Brent        Outer London
#
#    GLA Population Estimate 2017 GLA Household Estimate 2017  \
# 0                          8800                        5326
# 1                        209000                       78188
# 2                        389600                      151423
# 3                        244300                       97736
# 4                        332100                      121048
#
#   Inland Area (Hectares) Population density (per hectare) 2017  \
# 0                    290                                  30.3
# 1                   3611                                  57.9
# ...
